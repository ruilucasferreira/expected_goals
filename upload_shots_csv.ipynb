# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine, inspect

# %%
shots = pd.read_excel("shots.ods", engine="odf")
shots.index = shots.id
shots.drop(columns=["id"], inplace=True)

# %%
shots.head()
# Out:
#      game_id  player_id  team_id  minute  compensation  x_coord  y_coord  \
# id
# 104        5        204        3      27             0        6       37
# 105        5        215        3      28             0      -10       -1
# 106        5        215        3      34             0       11       35
# 107        5        216        3      46             0      -15       40
# 108        5        204        3      55             0       13       44
#
#       body_part                playtype          situation  ... assister_id  \
# id                                                          ...
# 104   Left Foot  After Defense Turnover                NaN  ...       221.0
# 105  Right Foot               Breakaway                NaN  ...         NaN
# 106  Right Foot               Breakaway                NaN  ...       216.0
# 107  Right Foot   After Short Clearance  After Left Corner  ...       221.0
# 108  Right Foot  After Defense Turnover                NaN  ...       191.0
#
#     pass_progression pass_distance  pass_height  gk_id  gk_x_coord  \
# id
# 104              0.0         Short          Low     43           0
# 105              NaN           NaN          NaN     43           0
# 106             30.0         Short          Low     43           1
# 107              0.0           Mid         High     43          -3
# 108             90.0         Short          Low     43           3
#
#      gk_y_coord  betrayal on_feet sofascore_xG
# id
# 104          52     False    True         0.12
# 105          32     False    True         0.03
# 106          51     False    True         0.05
# 107          51     False    True         0.02
# 108          51     False    True         0.06
#
# [5 rows x 26 columns]

# %%
user = "neondb_owner"
password = np.loadtxt("./neon_password.txt", dtype=str)
host = "ep-wild-night-a9bq078j-pooler.gwc.azure.neon.tech"
db = "xG"
engine = create_engine(f'postgresql://{user}:{password}@{host}/{db}')

inspector = inspect(engine)

# %%
shots.to_sql("game_shots", con=engine, if_exists="append")
# Out:
# 30
