# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine, inspect

# %%
shots = pd.read_excel("shots.ods", engine="odf")
shots.index = shots.id
shots.drop(columns=["id"], inplace=True)

# %%
shots.head()
# Out:
#     game_id  player_id  team_id  minute  compensation  x_coord  y_coord  \
# id
# 1         1         75        1       2             0       10       42
# 2         1         48        1       8             0        2       46
# 3         1         97        5      11             0       -7       43
# 4         1         80        1      15             0        7       44
# 5         1         80        1      31             0       16       42
#
#      body_part                playtype      situation  ...  \
# id                                                     ...
# 1    Left Foot       Organized Offense   Flank Change  ...
# 2         Head               Dead Ball   Right Corner  ...
# 3         Head               Dead Ball      Free Kick  ...
# 4   Right Foot       Organized Offense      Low Cross  ...
# 5   Right Foot  After Defense Turnover  After Dribble  ...
#
#    defenders_in_front_of_goal assister_id pass_progression  pass_distance  \
# id
# ...

# %%
user = "neondb_owner"
password = np.loadtxt("./neon_password.txt", dtype=str)
host = "ep-wild-night-a9bq078j-pooler.gwc.azure.neon.tech"
db = "xG"
engine = create_engine(f'postgresql://{user}:{password}@{host}/{db}')

inspector = inspect(engine)

# %%
#shots.to_sql("game_shots", con=engine, if_exists="append")
