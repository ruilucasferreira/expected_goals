# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine, inspect

# %%
shots = pd.read_excel("shots.ods", engine="odf")
shots.index = shots.id
shots.drop(columns=["id"], inplace=True)

# %%
shots.head()
# Out:
#     game_id  player_id  team_id  minute  compensation  x_coord  y_coord  \
# id
# 66        4        512       12      15             0        1     31.0
# 67        4         77        1      17             0        9     43.0
# 68        4        532       12      26             0       19      0.0
# 69        4         80        1      29             0      -15     40.0
# 70        4        532       12      31             0        5     41.0
#
#      body_part                playtype          situation  ... assister_id  \
# id                                                         ...
# 66   Left Foot               Dead Ball        Left Corner  ...         NaN
# 67  Right Foot  After Defense Turnover                NaN  ...        80.0
# 68  Right Foot  After Defense Turnover             Baloon  ...         NaN
# 69  Right Foot       Organized Offense  Individual Effort  ...        83.0
# 70  Right Foot       Organized Offense  Inside Area Cross  ...       506.0
#
#    pass_progression pass_distance  pass_height  gk_id  gk_x_coord  gk_y_coord  \
# id
# 66              NaN           NaN          NaN     43           0          50
# 67             45.0         Short          Low    505           3          49
# 68              NaN           NaN          NaN     43           0          36
# 69             60.0           Mid          Low    505          -3          51
# 70            -30.0           Mid          Low     43           2          52
#
#     betrayal on_feet sofascore_xG
# id
# 66     False    True         0.02
# 67     False    True         0.09
# 68     False    True         0.01
# 69      True    True         0.04
# 70     False    True         0.06
#
# [5 rows x 26 columns]

# %%
user = "neondb_owner"
password = np.loadtxt("./neon_password.txt", dtype=str)
host = "ep-wild-night-a9bq078j-pooler.gwc.azure.neon.tech"
db = "xG"
engine = create_engine(f'postgresql://{user}:{password}@{host}/{db}')

inspector = inspect(engine)

# %%
shots.to_sql("game_shots", con=engine, if_exists="append")
# Out:
# 37
